# %% [markdown]
# <p align = "center" draggable=”false” ><img src="https://user-images.githubusercontent.com/37101144/161836199-fdb0219d-0361-4988-bf26-48b0fad160a3.png"
#      width="200px"
#      height="auto"/>
# </p>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import streamlit as st
import shap

# Make NumPy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

print(tf.__version__)
# Out:
# 2022-12-08 19:00:14.650132: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-08 19:00:14.762543: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory
# 2022-12-08 19:00:14.762561: I tensorflow/compiler/xla/stream_executor/cuda/cudart_stub.cc:29] Ignore above cudart dlerror if you do not have a GPU set up on your machine.
# 2022-12-08 19:00:15.537634: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer.so.7'; dlerror: libnvinfer.so.7: cannot open shared object file: No such file or directory
# 2022-12-08 19:00:15.537758: W tensorflow/compiler/xla/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libnvinfer_plugin.so.7'; dlerror: libnvinfer_plugin.so.7: cannot open shared object file: No such file or directory
# 2022-12-08 19:00:15.537765: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Cannot dlopen some TensorRT libraries. If you would like to use Nvidia GPU with TensorRT, please make sure the missing libraries mentioned above are installed properly.
# 2.11.0

# %%
from tpot import TPOTRegressor, TPOTClassifier

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: ipython==8.4.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (8.4.0)
# Requirement already satisfied: matplotlib==3.5.2 in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (3.5.2)
# Requirement already satisfied: numpy==1.23.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.23.1)
# Requirement already satisfied: pandas==1.4.3 in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (1.4.3)
# Requirement already satisfied: plotly==5.9.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (5.9.0)
# Requirement already satisfied: scikit_learn==1.1.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (1.1.1)
# Requirement already satisfied: seaborn==0.11.2 in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (0.11.2)
# Requirement already satisfied: shap in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 8)) (0.41.0)
# Requirement already satisfied: streamlit==1.11.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (1.11.1)
# Collecting tensorflow
#   Downloading tensorflow-2.11.0-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (588.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 588.3/588.3 MB 6.7 MB/s eta 0:00:0000:0100:01
# Collecting tpot
#   Using cached TPOT-0.11.7-py3-none-any.whl (87 kB)
# Requirement already satisfied: jedi>=0.16 in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: stack-data in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.6.2)
# Requirement already satisfied: setuptools>=18.5 in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (58.0.4)
# Requirement already satisfied: backcall in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: decorator in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (5.1.0)
# Requirement already satisfied: pexpect>4.3 in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (5.1.0)
# Requirement already satisfied: pygments>=2.4.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (2.13.0)
# Requirement already satisfied: pickleshare in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from ipython==8.4.0->-r requirements.txt (line 1)) (3.0.20)
# Requirement already satisfied: fonttools>=4.22.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (21.3)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (3.0.9)
# Requirement already satisfied: pillow>=6.2.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (8.4.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/jong/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /home/jong/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from matplotlib==3.5.2->-r requirements.txt (line 2)) (1.3.1)
# Requirement already satisfied: pytz>=2020.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from pandas==1.4.3->-r requirements.txt (line 4)) (2022.5)
# Requirement already satisfied: tenacity>=6.2.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from plotly==5.9.0->-r requirements.txt (line 5)) (8.1.0)
# Requirement already satisfied: scipy>=1.3.2 in /home/jong/anaconda3/lib/python3.9/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (1.9.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (2.2.0)
# Requirement already satisfied: joblib>=1.0.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from scikit_learn==1.1.1->-r requirements.txt (line 6)) (1.1.0)
# Requirement already satisfied: validators>=0.2 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (0.20.0)
# Requirement already satisfied: pympler>=0.9 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (1.0.1)
# Requirement already satisfied: gitpython!=3.1.19 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (3.1.29)
# Requirement already satisfied: rich>=10.11.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (12.6.0)
# Requirement already satisfied: importlib-metadata>=1.4 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (5.0.0)
# Requirement already satisfied: requests>=2.4 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (2.28.1)
# Requirement already satisfied: click>=7.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (8.1.3)
# Requirement already satisfied: attrs>=16.0.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (22.1.0)
# Requirement already satisfied: protobuf<4,>=3.12 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (3.20.3)
# Requirement already satisfied: tornado>=5.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (6.1)
# Requirement already satisfied: watchdog in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (2.1.3)
# Requirement already satisfied: pydeck>=0.1.dev5 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (0.8.0)
# Requirement already satisfied: semver in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (2.13.0)
# Requirement already satisfied: toml in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (0.10.2)
# Requirement already satisfied: tzlocal>=1.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (4.2)
# Requirement already satisfied: typing-extensions>=3.10.0.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (4.4.0)
# Requirement already satisfied: altair>=3.2.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (4.2.0)
# Requirement already satisfied: blinker>=1.0.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (1.5)
# Requirement already satisfied: pyarrow>=4.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (9.0.0)
# Requirement already satisfied: cachetools>=4.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from streamlit==1.11.1->-r requirements.txt (line 9)) (5.2.0)
# Requirement already satisfied: cloudpickle in /home/jong/anaconda3/lib/python3.9/site-packages (from shap->-r requirements.txt (line 8)) (2.0.0)
# Requirement already satisfied: slicer==0.0.7 in /home/jong/anaconda3/lib/python3.9/site-packages (from shap->-r requirements.txt (line 8)) (0.0.7)
# Requirement already satisfied: tqdm>4.25.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from shap->-r requirements.txt (line 8)) (4.62.3)
# Requirement already satisfied: numba in /home/jong/anaconda3/lib/python3.9/site-packages (from shap->-r requirements.txt (line 8)) (0.56.4)
# Requirement already satisfied: tensorboard<2.12,>=2.11 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 10)) (2.11.0)
# Requirement already satisfied: astunparse>=1.6.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.16.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.51.1)
# Requirement already satisfied: absl-py>=1.0.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.3.0)
# Collecting keras<2.12,>=2.11.0
#   Downloading keras-2.11.0-py2.py3-none-any.whl (1.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 19.8 MB/s eta 0:00:00a 0:00:01
# Collecting flatbuffers>=2.0
#   Downloading flatbuffers-22.12.6-py2.py3-none-any.whl (26 kB)
# Collecting tensorflow-estimator<2.12,>=2.11.0
#   Downloading tensorflow_estimator-2.11.0-py2.py3-none-any.whl (439 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 439.2/439.2 kB 18.3 MB/s eta 0:00:00
# Collecting google-pasta>=0.1.1
#   Using cached google_pasta-0.2.0-py3-none-any.whl (57 kB)
# Collecting libclang>=13.0.0
#   Using cached libclang-14.0.6-py2.py3-none-manylinux2010_x86_64.whl (14.1 MB)
# Requirement already satisfied: wrapt>=1.11.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 10)) (1.14.1)
# Requirement already satisfied: termcolor>=1.1.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 10)) (2.0.1)
# Collecting opt-einsum>=2.3.2
#   Using cached opt_einsum-3.3.0-py3-none-any.whl (65 kB)
# Requirement already satisfied: h5py>=2.9.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorflow->-r requirements.txt (line 10)) (3.3.0)
# Collecting tensorflow-io-gcs-filesystem>=0.23.1
#   Downloading tensorflow_io_gcs_filesystem-0.28.0-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (2.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 16.7 MB/s eta 0:00:0000:0100:01
# Collecting protobuf<4,>=3.12
#   Downloading protobuf-3.19.6-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 13.4 MB/s eta 0:00:0000:0100:01
# Collecting gast<=0.4.0,>=0.2.1
#   Using cached gast-0.4.0-py3-none-any.whl (9.8 kB)
# Requirement already satisfied: update-checker>=0.16 in /home/jong/anaconda3/lib/python3.9/site-packages (from tpot->-r requirements.txt (line 11)) (0.18.0)
# Collecting stopit>=1.1.1
#   Using cached stopit-1.1.2.tar.gz (18 kB)
#   Preparing metadata (setup.py) ... done
# Collecting deap>=1.2
#   Downloading deap-1.3.3-cp39-cp39-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 9.5 MB/s eta 0:00:00
# Collecting xgboost>=1.1.0
#   Downloading xgboost-1.7.2-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.6/193.6 MB 9.2 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: jsonschema>=3.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (4.16.0)
# Requirement already satisfied: entrypoints in /home/jong/anaconda3/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.3)
# Requirement already satisfied: toolz in /home/jong/anaconda3/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.11.1)
# Requirement already satisfied: jinja2 in /home/jong/anaconda3/lib/python3.9/site-packages (from altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (3.1.2)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 10)) (0.37.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from gitpython!=3.1.19->streamlit==1.11.1->-r requirements.txt (line 9)) (4.0.10)
# Requirement already satisfied: zipp>=0.5 in /home/jong/anaconda3/lib/python3.9/site-packages (from importlib-metadata>=1.4->streamlit==1.11.1->-r requirements.txt (line 9)) (3.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython==8.4.0->-r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: ptyprocess>=0.5 in /home/jong/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->ipython==8.4.0->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: wcwidth in /home/jong/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython==8.4.0->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (1.26.12)
# Requirement already satisfied: idna<4,>=2.5 in /home/jong/anaconda3/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/jong/anaconda3/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (2022.9.24)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/jong/anaconda3/lib/python3.9/site-packages (from requests>=2.4->streamlit==1.11.1->-r requirements.txt (line 9)) (2.1.1)
# Requirement already satisfied: commonmark<0.10.0,>=0.9.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from rich>=10.11.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.9.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (2.15.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (0.6.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (0.4.6)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (2.2.2)
# Requirement already satisfied: markdown>=2.6.8 in /home/jong/anaconda3/lib/python3.9/site-packages (from tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (3.4.1)
# Requirement already satisfied: pytz-deprecation-shim in /home/jong/anaconda3/lib/python3.9/site-packages (from tzlocal>=1.1->streamlit==1.11.1->-r requirements.txt (line 9)) (0.1.0.post0)
# Requirement already satisfied: llvmlite<0.40,>=0.39.0dev0 in /home/jong/anaconda3/lib/python3.9/site-packages (from numba->shap->-r requirements.txt (line 8)) (0.39.1)
# Requirement already satisfied: executing>=1.2.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from stack-data->ipython==8.4.0->-r requirements.txt (line 1)) (1.2.0)
# Requirement already satisfied: pure-eval in /home/jong/anaconda3/lib/python3.9/site-packages (from stack-data->ipython==8.4.0->-r requirements.txt (line 1)) (0.2.2)
# Requirement already satisfied: asttokens>=2.1.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from stack-data->ipython==8.4.0->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: smmap<6,>=3.0.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19->streamlit==1.11.1->-r requirements.txt (line 9)) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/jong/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/jong/anaconda3/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (1.3.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from jinja2->altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (2.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from jsonschema>=3.0->altair>=3.2.0->streamlit==1.11.1->-r requirements.txt (line 9)) (0.18.1)
# Requirement already satisfied: tzdata in /home/jong/anaconda3/lib/python3.9/site-packages (from pytz-deprecation-shim->tzlocal>=1.1->streamlit==1.11.1->-r requirements.txt (line 9)) (2022.7)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/jong/anaconda3/lib/python3.9/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/jong/anaconda3/lib/python3.9/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.12,>=2.11->tensorflow->-r requirements.txt (line 10)) (3.2.2)
# Building wheels for collected packages: stopit
#   Building wheel for stopit (setup.py) ... done
#   Created wheel for stopit: filename=stopit-1.1.2-py3-none-any.whl size=11952 sha256=6ea0ae1d4286d8f7b764fda0f2fea5e62b7c395f22b4049e19ef81bad7e82425
#   Stored in directory: /home/jong/.cache/pip/wheels/3f/2c/f9/411eea50089f1313eb80637f6107ec839721f6e36679050160
# Successfully built stopit
# Installing collected packages: stopit, libclang, flatbuffers, tensorflow-io-gcs-filesystem, tensorflow-estimator, protobuf, opt-einsum, keras, google-pasta, gast, deap, xgboost, tpot, tensorflow
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
# Successfully installed deap-1.3.3 flatbuffers-22.12.6 gast-0.4.0 google-pasta-0.2.0 keras-2.11.0 libclang-14.0.6 opt-einsum-3.3.0 protobuf-3.19.6 stopit-1.1.2 tensorflow-2.11.0 tensorflow-estimator-2.11.0 tensorflow-io-gcs-filesystem-0.28.0 tpot-0.11.7 xgboost-1.7.2
#
# [notice] A new release of pip available: 22.3 -> 22.3.1
# [notice] To update, run: pip install --upgrade pip
